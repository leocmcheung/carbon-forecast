# %%
import pandas as pd

# %%
data = pd.read_csv('../../mcussac/data_forecast_carbon/Fossil_Fuel_Energy_Mix.csv')
data.head()
# Out:
#    TCUID                                         Company          ISIN  \
# 0  42782                          RWE Aktiengesellschaft  DE0007037129
# 1  44525                                        Enel SpA  IT0003128367
# 2  49649  China Resources Power Holdings Company Limited  HK0836012952
# 3  42782                          RWE Aktiengesellschaft  DE0007037129
# 4  44525                                        Enel SpA  IT0003128367
#
#    Financial Year  GICS Sector Code GICS Sector Name  \
# 0            2005                55        Utilities
# 1            2005                55        Utilities
# 2            2005                55        Utilities
# 3            2006                55        Utilities
# 4            2006                55        Utilities
#
#    GICS Industry Group Code GICS Industry Group Name  GICS Industry Code  \
# 0                      5510                Utilities              551030
# ...

# %%
data.columns
# Out:
# Index(['TCUID', 'Company', 'ISIN', 'Financial Year', 'GICS Sector Code',
#        'GICS Sector Name', 'GICS Industry Group Code',
#        'GICS Industry Group Name', 'GICS Industry Code', 'GICS Industry Name',
#        'GICS Sub Industry Code', 'GICS Sub Industry Name', 'GICS Description',
#        'Country', 'Reserves 1P Metallurgical Coal (m tonnes)',
#        'Reserves 2P Metallurgical Coal (m tonnes)',
#        'Reserves 1P Thermal Coal (m tonnes)',
#        'Reserves 2P Thermal Coal (m tonnes)',
#        'Reserves 1P Other Coal (m tonnes)',
#        'Reserves 2P Other Coal (m tonnes)',
#        'Reserves 1P Conventional Oil (mmbbl)',
#        'Reserves 2P Conventional Oil (mmbbl)',
#        'Reserves 1P Unconventional Oil (mmbbl)',
#        'Reserves 2P Unconventional Oil (mmbbl)',
#        'Reserves 1P Natural Gas (bcf)', 'Reserves 2P Natural Gas (bcf)',
#        'Reserves 1P Shale Gas (bcf)', 'Reserves 2P Shale Gas (bcf)',
# ...

# %%
data['coal_reserves'] = data['Reserves 2P Metallurgical Coal (m tonnes)']\
                        + data['Reserves 2P Thermal Coal (m tonnes)']\
                        + data['Reserves 2P Other Coal (m tonnes)']\
                        + data['Reserves 2P Conventional Oil (mmbbl)']\
                        + data['Reserves 2P Unconventional Oil (mmbbl)']

# %%
data.shape
# Out:
# (6939, 67)

# %%
data_energy_sector = data[data['GICS Sector Name'] =='Energy']

# %%
data_energy_sector.shape
# Out:
# (2889, 67)

# %%
tmp = data_energy_sector[data_energy_sector['Reserves 2P Metallurgical Coal (m tonnes)'] != 'Not Relevant']

# %%
tmp[tmp['Reserves 2P Metallurgical Coal (m tonnes)'] != 'Not Relevant']
# Out:
#        TCUID                       Company          ISIN  Financial Year  \
# 57    108728          ENEOS Holdings, Inc.  JP3386450005            2011
# 104    43675    PTT Public Company Limited  TH0646010Z00            2012
# 177    45239    Peabody Energy Corporation  US7045511000            2012
# 179    45518          Arch Resources, Inc.  US03940R1077            2012
# 187    46190     CNX Resources Corporation  US12653C1080            2012
# ...      ...                           ...           ...             ...
# 6913  246006     Sundiro Holding Co., Ltd.  CNE000000586            2020
# 6914  246007              TerraCom Limited  AU000000TER9            2020
# 6916  246009   Vinacomin - DeoNai Coal JSC  VN000000TDN1            2020
# 6917  246010    Vinacomin - Ha Tu Coal JSC  VN000000THT9            2020
# 6918  246011  Vinacomin - Nui Beo Coal JSC  VN000000NBC1            2020
#
#       GICS Sector Code GICS Sector Name  GICS Industry Group Code  \
# ...

# %%
tmp[['Reserves 2P Metallurgical Coal (m tonnes)', 'Reserves 1P Metallurgical Coal (m tonnes)', 'Reserves CO2 emissions from Coal (m tonnes)']].head(50)
# Out:
#     Reserves 2P Metallurgical Coal (m tonnes)  \
# 57                              Not Disclosed
# 104                             Not Disclosed
# 177                                    281.22
# 179                             Not Disclosed
# 187                                    469.35
# 218                             Not Disclosed
# 314                             Not Disclosed
# 321                             Not Disclosed
# 329                             Not Disclosed
# 335                             Not Disclosed
# 349                             Not Disclosed
# 351                             Not Disclosed
# 372                                    518.14
# 387                             Not Disclosed
# 392                                    694.70
# 393                                   1980.00
# 396                             Not Disclosed
# 398                             Not Disclosed
# 418                             Not Disclosed
# ...

# %%
to_drop = 'TCUID', 'Company', 'Financial Year',
       'GICS Sector Name',
       'GICS Industry Group Name', 'GICS Industry Name',
       'GICS Sub Industry Name','Reserves CO2 emissions from Coal (m tonnes)',
       'Reserves CO2 emissions from Oil (m tonnes)',
       'Reserves CO2 emissions from Gas (m tonnes)',
       'Reserves CO2 emissions from Oil + Gas (m tonnes)',
       'Coal Power Generation (GWh)', 'Natural Gas Power Generation (GWh)',
       'LPG Power Generation (GWh)', 'Petroleum Power Generation (GWh)',
       'LNG Power Generation (GWh)', 'Wind Power Generation (GWh)',
       'Solar Power Generation (GWh)', 'Biomass Power Generation (GWh)',
       'Geothermal Power Generation (GWh)',
       'Wave & Tidal Power Generation (GWh)',
       'Hydroelectric Power Generation (GWh)',
       'Nuclear Power Generation (GWh)', 'Landfill Gas Power Generation (GWh)',
       'Other Power Generation (GWh)',
       'Coal Power Generation GHG (tonnes CO2e)',
       'Natural Gas Power Generation GHG (tonnes CO2e)',
       'LPG Power Generation GHG (tonnes CO2e)',
       'Petroleum Power Generation GHG (tonnes CO2e)',
       'LNG Power Generation GHG (tonnes CO2e)', 'CAPEX Coal (m USD)',
       'CAPEX Oil (m USD)', 'CAPEX Gas (m USD)', 'CAPEX Oil & Gas (m USD)',
       'CAPEX Other exploration (m USD)', 'Coal Gasification',
       'Coal Liquefaction', 'Total Reserves CO2 emissions (m tonnes)',
       'Total Energy Generation CO2e Emissions (tonnes)', 'FigureRestate',
       'EffectiveDate'

# %%
tmp1 = data[data['Coal Gasification'] != 'Not Relevant']
tmp1[tmp1['Coal Gasification'] != 'Not Disclosed']
# Out:
#        TCUID                                            Company          ISIN  \
# 177    45239                         Peabody Energy Corporation  US7045511000
# 449    86788                            Lanco Infratech Limited  INE785C01048
# 461   108874                         TAURON Polska Energia S.A.  PLTAURN00011
# 653    45239                         Peabody Energy Corporation  US7045511000
# 961   108874                         TAURON Polska Energia S.A.  PLTAURN00011
# 1236   45239                         Peabody Energy Corporation  US7045511000
# 1352   49649     China Resources Power Holdings Company Limited  HK0836012952
# 1451   54306                                         Mechel PAO  US5838406081
# 1510   84330                            New World Resources Plc  GB00B42CTW68
# 1842   45239                         Peabody Energy Corporation  US7045511000
# 1971   51408                       Jindal Steel & Power Limited  INE749A01030
# ...

# %%
data.columns
# Out:
# Index(['TCUID', 'Company', 'ISIN', 'Financial Year', 'GICS Sector Code',
#        'GICS Sector Name', 'GICS Industry Group Code',
#        'GICS Industry Group Name', 'GICS Industry Code', 'GICS Industry Name',
#        'GICS Sub Industry Code', 'GICS Sub Industry Name', 'GICS Description',
#        'Country', 'Reserves 1P Metallurgical Coal (m tonnes)',
#        'Reserves 2P Metallurgical Coal (m tonnes)',
#        'Reserves 1P Thermal Coal (m tonnes)',
#        'Reserves 2P Thermal Coal (m tonnes)',
#        'Reserves 1P Other Coal (m tonnes)',
#        'Reserves 2P Other Coal (m tonnes)',
#        'Reserves 1P Conventional Oil (mmbbl)',
#        'Reserves 2P Conventional Oil (mmbbl)',
#        'Reserves 1P Unconventional Oil (mmbbl)',
#        'Reserves 2P Unconventional Oil (mmbbl)',
#        'Reserves 1P Natural Gas (bcf)', 'Reserves 2P Natural Gas (bcf)',
#        'Reserves 1P Shale Gas (bcf)', 'Reserves 2P Shale Gas (bcf)',
# ...

# %%
features = ['Reserves CO2 emissions from Coal (m tonnes)',
       'Reserves CO2 emissions from Oil (m tonnes)',
       'Reserves CO2 emissions from Gas (m tonnes)',
       'Reserves CO2 emissions from Oil + Gas (m tonnes)']

# %%
t1 = data.pivot_table(index="Company", columns="Financial Year", values='Reserves CO2 emissions from Coal (m tonnes)').reset_index()
t1["Data Type"] = 'Reserves CO2 emissions from Coal (m tonnes)'
cols =['Company','Data Type', 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# t1 = t1[cols]
# t1
# Out:
# /var/folders/0t/zk0ndrrj3c5cgn1mjj3mnn_40000gp/T/ipykernel_43107/4267665220.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   t1 = data.pivot_table(index="Company", columns="Financial Year", values='Reserves CO2 emissions from Coal (m tonnes)').reset_index()

# %%
t1
# Out:
# Financial Year                                            Company  \
# 0                                               7C Solarparken AG
# 1                                                      A2A S.p.A.
# 2                                     AAG Energy Holdings Limited
# 3                                                AB Ignitis grupe
# 4                          ABU DHABI NATIONAL ENERGY COMPANY PJSC
# ...                                                           ...
# 1297                    Zhejiang Zheneng Electric Power Co., Ltd.
# 1298            Zhongman Petroleum and Natural Gas Group Corp....
# 1299            Zhongxing Tianheng Energy Technology (Beijing)...
# 1300                                Zorlu Enerji Elektrik Uretimi
# 1301                                                eREX Co.,Ltd.
#
# Financial Year                                    Data Type
# 0               Reserves CO2 emissions from Coal (m tonnes)
# ...
