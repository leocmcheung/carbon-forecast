# %%
# %load_ext autoreload
# %autoreload 2

# %%
from carbon_forecast.utils.data_related import show_sector
import pandas as pd
import numpy as np

# %%
df = show_sector()
# Out:
# Which GICS Sector?Energy
# Reading data...
# Getting rid of 2021 incomplete data...
# Adding scope1&2 -> For absolute please look 'C-absolute-1+2'
#  For intensity please look 'C-intensity-1+2'
# Filtering by GICS Industry Name
# Done!

# %%
df
# Out:
#          TCUID                    Company  Financial Year GICS Sector Name  \
# 210      42717  Woodside Energy Group Ltd            2007           Energy
# 211      42717  Woodside Energy Group Ltd            2008           Energy
# 212      42717  Woodside Energy Group Ltd            2009           Energy
# 213      42717  Woodside Energy Group Ltd            2010           Energy
# 214      42717  Woodside Energy Group Ltd            2011           Energy
# ...        ...                        ...             ...              ...
# 130410  247360      JC Chemical Co., Ltd.            2020           Energy
# 130565  247533   New Fortress Energy Inc.            2020           Energy
# 130627  247608   Peninsula Energy Limited            2020           Energy
# 130631  247612        Petroreconcavo S.A.            2020           Energy
# 130836  247816      Technip Energies N.V.            2020           Energy
#
#        GICS Industry Group Name           GICS Industry Name  \
# 210                      Energy  Oil, Gas & Consumable Fuels
# 211                      Energy  Oil, Gas & Consumable Fuels
# 212                      Energy  Oil, Gas & Consumable Fuels
# 213                      Energy  Oil, Gas & Consumable Fuels
# 214                      Energy  Oil, Gas & Consumable Fuels
# ...                         ...                          ...
# 130410                   Energy  Oil, Gas & Consumable Fuels
# 130565                   Energy  Oil, Gas & Consumable Fuels
# 130627                   Energy  Oil, Gas & Consumable Fuels
# 130631                   Energy  Oil, Gas & Consumable Fuels
# 130836                   Energy  Energy Equipment & Services
#
#                     GICS Sub Industry Name  Carbon-Scope 1 (tonnes CO2e)  \
# 210     Oil & Gas Exploration & Production                  1.643806e+06
# 211     Oil & Gas Exploration & Production                  1.979545e+06
# 212     Oil & Gas Exploration & Production                  2.516979e+06
# 213     Oil & Gas Exploration & Production                  2.258013e+06
# 214     Oil & Gas Exploration & Production                  1.888694e+06
# ...                                    ...                           ...
# 130410      Oil & Gas Refining & Marketing                  5.104816e+04
# 130565      Oil & Gas Refining & Marketing                  9.678890e+05
# 130627             Coal & Consumable Fuels                  6.553500e+02
# 130631  Oil & Gas Exploration & Production                  6.455879e+04
# 130836      Oil & Gas Equipment & Services                  1.124100e+05
#
#         Carbon-Scope 2 (tonnes CO2e)  \
# 210                      8724.780000
# 211                      8923.626481
# 212                      8389.174554
# 213                     22282.000000
# 214                     18637.580078
# ...                              ...
# 130410                   7240.055000
# 130565                  46781.000000
# 130627                   1618.294000
# 130631                   7419.849000
# 130836                  88387.833000
#
#         Carbon Intensity-Scope 1 (tonnes CO2e/USD mn)  \
# 210                                        468.018306
# 211                                        480.180974
# 212                                        643.075650
# 213                                        538.519653
# 214                                        393.314101
# ...                                               ...
# 130410                                     224.955000
# 130565                                    2143.007000
# 130627                                     107.823000
# 130631                                     421.942000
# 130836                                      17.157000
#
#         Carbon Intensity-Scope 2 (tonnes CO2e/USD mn)  \
# 210                                          2.484087
# 211                                          2.164616
# 212                                          2.143393
# 213                                          5.314095
# 214                                          3.881212
# ...                                               ...
# 130410                                      31.905000
# 130565                                     103.578000
# 130627                                     266.254000
# 130631                                      48.495000
# 130836                                      13.491000
#
#         Carbon-Weighted Disclosure (%)  Revenue (USD mn)  C-absolute-1+2  \
# 210                              100.0       3512.268000    1.652530e+06
# 211                              100.0       4122.497845    1.988469e+06
# 212                              100.0       3913.970000    2.525368e+06
# 213                              100.0       4193.000000    2.280295e+06
# 214                              100.0       4802.000000    1.907332e+06
# ...                                ...               ...             ...
# 130410                             0.0        226.925832    5.828821e+04
# 130565                           100.0        451.650000    1.014670e+06
# 130627                             0.0          6.078000    2.273644e+03
# 130631                             0.0        153.003893    7.197864e+04
# 130836                             0.0       6551.749716    2.007978e+05
#
#         C-intensity-1+2
# 210          470.502393
# 211          482.345590
# 212          645.219042
# 213          543.833748
# 214          397.195313
# ...                 ...
# 130410       256.860000
# 130565      2246.585000
# 130627       374.077000
# 130631       470.437000
# 130836        30.648000
#
# [6186 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['TCUID', 'Company', 'Financial Year', 'GICS Sector Name',
#        'GICS Industry Group Name', 'GICS Industry Name',
#        'GICS Sub Industry Name', 'Carbon-Scope 1 (tonnes CO2e)',
#        'Carbon-Scope 2 (tonnes CO2e)',
#        'Carbon Intensity-Scope 1 (tonnes CO2e/USD mn)',
#        'Carbon Intensity-Scope 2 (tonnes CO2e/USD mn)',
#        'Carbon-Weighted Disclosure (%)', 'Revenue (USD mn)', 'C-absolute-1+2',
#        'C-intensity-1+2'],
#       dtype='object')

# %%
len(df.TCUID.unique())
# Out:
# 928

# %%
to_drop = ['GICS Sector Name',
       'GICS Industry Group Name', 'GICS Industry Name',
       'GICS Sub Industry Name', 'Carbon-Scope 1 (tonnes CO2e)',
       'Carbon-Scope 2 (tonnes CO2e)',
       'Carbon Intensity-Scope 1 (tonnes CO2e/USD mn)',
       'Carbon Intensity-Scope 2 (tonnes CO2e/USD mn)',
       'Carbon-Weighted Disclosure (%)', 'Revenue (USD mn)', 'C-intensity-1+2']

# %%
df.drop(columns=to_drop, inplace=True)

# %%
df_year = df.pivot_table(index=["TCUID", "Company"], columns="Financial Year", values="C-absolute-1+2").reset_index()

# %%
df_year
# Out:
# Financial Year   TCUID                                 Company          2005  \
# 0                42717               Woodside Energy Group Ltd           NaN
# 1                42736                  Nabors Industries Ltd.  6.357449e+05
# 2                42752  China Petroleum & Chemical Corporation  2.099295e+07
# 3                42759              PetroChina Company Limited  3.195179e+07
# 4                42804                            Repsol, S.A.  2.788101e+07
# ..                 ...                                     ...           ...
# 923             247360                   JC Chemical Co., Ltd.           NaN
# 924             247533                New Fortress Energy Inc.           NaN
# 925             247608                Peninsula Energy Limited           NaN
# 926             247612                     Petroreconcavo S.A.           NaN
# 927             247816                   Technip Energies N.V.           NaN
#
# Financial Year          2006          2007          2008          2009  \
# 0                        NaN  1.652530e+06  1.988469e+06  2.525368e+06
# 1               7.464925e+05  7.127640e+05  6.417752e+05  5.017894e+05
# 2               2.414293e+07  2.497737e+07  2.691440e+07  2.235403e+07
# 3               3.177384e+07  4.116426e+07  4.694361e+07  5.045039e+07
# 4               2.887125e+07  2.692955e+07  2.958920e+07  2.662171e+07
# ..                       ...           ...           ...           ...
# 923                      NaN           NaN           NaN           NaN
# 924                      NaN           NaN           NaN           NaN
# 925                      NaN           NaN           NaN           NaN
# 926                      NaN           NaN           NaN           NaN
# 927                      NaN           NaN           NaN           NaN
#
# Financial Year          2010          2011          2012          2013  \
# 0               2.280295e+06  1.907332e+06  3.853622e+06  9.892521e+06
# 1               5.714058e+05  6.245800e+05  7.214755e+05  6.733347e+05
# 2               3.160034e+07  4.439308e+07  4.025447e+07  4.100530e+07
# 3               6.587769e+07  9.735470e+07  9.169841e+07  9.930575e+07
# 4               2.546006e+07  2.471139e+07  1.487893e+07  1.516315e+07
# ..                       ...           ...           ...           ...
# 923                      NaN           NaN           NaN           NaN
# 924                      NaN           NaN           NaN           NaN
# 925                      NaN           NaN           NaN           NaN
# 926                      NaN           NaN           NaN           NaN
# 927                      NaN           NaN           NaN           NaN
#
# Financial Year          2014          2015          2016  2017           2018  \
# 0               1.001485e+07  1.011950e+07           NaN   NaN            NaN
# 1               7.319099e+05  4.889185e+05           NaN   NaN  378450.153985
# 2               3.710075e+07  2.840816e+07           NaN   NaN            NaN
# 3               8.618106e+07  3.822520e+07  3.687689e+07   NaN            NaN
# 4               1.484729e+07  2.164376e+07           NaN   NaN            NaN
# ..                       ...           ...           ...   ...            ...
# 923                      NaN           NaN           NaN   NaN            NaN
# 924                      NaN           NaN           NaN   NaN            NaN
# 925                      NaN           NaN           NaN   NaN            NaN
# 926                      NaN           NaN           NaN   NaN            NaN
# 927                      NaN           NaN           NaN   NaN            NaN
#
# Financial Year  2019          2020
# 0                NaN  9.180000e+06
# 1                NaN  1.116173e+06
# 2                NaN  1.709400e+08
# 3                NaN  1.674400e+08
# 4                NaN           NaN
# ..               ...           ...
# 923              NaN  5.828821e+04
# 924              NaN  1.014670e+06
# 925              NaN  2.273644e+03
# 926              NaN  7.197864e+04
# 927              NaN  2.007978e+05
#
# [928 rows x 18 columns]

# %%
df_year.to_csv("../raw_data/for_RNN_energy.csv", index=False)

# %%
df.pivot_table(index="Financial Year", columns=["Company"], values="C-absolute-1+2").reset_index().to_csv("../raw_data/for_RNN_energy.csv")
