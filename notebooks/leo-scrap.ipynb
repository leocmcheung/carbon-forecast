# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/leo/code/leocmcheung/carbon-forecast/notebooks

# %%
data = pd.read_csv("../raw_data/Truc_GHG_CPUCPCU_AllYr_20220903.csv")
data.head()
# Out:
#    TCUID              Company          ISIN  Financial Year  GICS Sector Code  \
# 0  42694  Erste Group Bank AG  AT0000652011            2005              40.0
# 1  42694  Erste Group Bank AG  AT0000652011            2006              40.0
# 2  42694  Erste Group Bank AG  AT0000652011            2007              40.0
# 3  42694  Erste Group Bank AG  AT0000652011            2008              40.0
# 4  42694  Erste Group Bank AG  AT0000652011            2009              40.0
#
#   GICS Sector Name  GICS Industry Group Code GICS Industry Group Name  \
# 0       Financials                    4010.0                    Banks
# 1       Financials                    4010.0                    Banks
# 2       Financials                    4010.0                    Banks
# 3       Financials                    4010.0                    Banks
# 4       Financials                    4010.0                    Banks
#
# ...

# %%
data["GICS Industry Group Name"].unique().tolist()
# Out:
# ['Banks',
#  'Telecommunication Services',
#  'Materials',
#  'Insurance',
#  'Diversified Financials',
#  'Food & Staples Retailing',
#  'Food, Beverage & Tobacco',
#  'Capital Goods',
#  'Retailing',
#  'Energy',
#  'Pharmaceuticals, Biotechnology & Life Sciences',
#  'Consumer Durables & Apparel',
#  'Health Care Equipment & Services',
#  'Technology Hardware & Equipment',
#  'Commercial  & Professional Services',
#  'Utilities',
#  'Household & Personal Products',
#  'Automobiles & Components',
#  'Transportation',
#  'Semiconductors & Semiconductor Equipment',
#  'Software & Services',
#  'Consumer Services',
#  'Media (discont. 2018)',
#  'Media & Entertainment',
#  'Real Estate',
#  nan]

# %%
data2 = pd.read_excel("../raw_data/7_26_2022 CEAR output.xlsx")

# %%
data2
# Out:
#         TCUID                                            Company  \
# 0       42694                                Erste Group Bank AG
# 1       42695                                 Telekom Austria AG
# 2       42696                                          Amcor plc
# 3       42697                                        AMP Limited
# 4       42698    Australia and New Zealand Banking Group Limited
# ...       ...                                                ...
# 16728  248168                                      Traeger, Inc.
# 16729  248169                                         Weber Inc.
# 16730  248200  Getnet Adquirencia e Servicos para Meios de Pa...
# 16731  248219                                Sylvamo Corporation
# 16732  248243                        Apartment Income REIT Corp.
#
#                ISIN  Financial Year            GICS Sector Name  \
# 0      AT0000652011            2020  Residential and Commercial
# ...

# %%
data3 = pd.read_excel("../raw_data/Client_RenEnergyCapex&OtherData_20211206.xlsx")
data3
# Out:
#          MI ID    TCUID          ISIN  Year  \
# 0      3007562  43842.0  US30231G1022  2021
# 1      3007562  43842.0  US30231G1022  2021
# 2      3007562  43842.0  US30231G1022  2021
# 3      3007562  43842.0  US30231G1022  2021
# 4      3007562  43842.0  US30231G1022  2021
# ...        ...      ...           ...   ...
# 6379  20248851      NaN           NaN  2021
# 6380  20248851      NaN           NaN  2021
# 6381  20248851      NaN           NaN  2021
# 6382  20248851      NaN           NaN  2021
# 6383  20248851      NaN           NaN  2021
#
#                                     Company Name  \
# 0                        Exxon Mobil Corporation
# 1                        Exxon Mobil Corporation
# 2                        Exxon Mobil Corporation
# 3                        Exxon Mobil Corporation
# 4                        Exxon Mobil Corporation
# ...                                          ...
# 6379  Doral Group Renewable Energy Resources Ltd
# ...
